# %%
# 役割や前提の設定
role = "あなたはマーケティング分野に精通したビジネスコンサルタントです。企業の成長をサポートするために、効果的なマーケティング戦略を提供します。"

# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# メッセージの設定
message = "新製品の発売に向けた効果的なマーケティング戦略を教えてください。"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": message},
    ],
)

# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 新製品の発売に向けて効果的なマーケティング戦略を構築するためには、以下のステップを考慮することが重要です。
#
# ### 1. 市場調査
# - **ターゲット市場の特定**: 製品が最も響く顧客層を分析し、ペルソナを作成します。
# - **競合分析**: 競合他社の製品や戦略を調査し、自社の差別化ポイントを明確にします。
#
# ### 2. ブランドポジショニング
# - **ユニークバリュープロポジション (UVP)**: 製品の独自性を強調するメッセージを作成します。顧客にとっての利点を明確に伝えましょう。
#
# ### 3. マーケティングチャネルの選定
# - **デジタルマーケティング**: SNSやWeb広告、メールマーケティングなどを活用し、広範囲に情報を発信します。
# - **オフラインマーケティング**: イベントや展示会、店舗内プロモーションなども考慮し、ターゲットと直接接触する機会を設けます。
#
# ### 4. プロモーション戦略
# - **事前キャンペーン**: 製品発売前に「ティーザー」キャンペーンを展開し、期待感を高めます。サンプルの配布やインフルエンサーとの連携も効果的です。
# - **ローンチイベント**: オンラインまたはオフラインでの製品発表イベントを開催し、メディアや顧客を招待して製品体験を提供します。
#
# ### 5. オムニチャネル戦略
# - **一貫したメッセージ**: オンラインとオフラインを通じて、同じブランドメッセージと体験を提供することが重要です。
# - **セグメンテーション**: 顧客の属性や行動に基づいてカスタマイズしたメッセージを展開し、関心を引きます。
#
# ### 6. フィードバックと改善
# - **顧客の声を反映**: 製品発売後に顧客からのフィードバックを収集し、必要に応じて戦略や製品の改善を図ります。
# - **分析と調整**: キャンペーンの結果を分析し、どのチャネルやメッセージが効果的だったかを検証し、次のキャンペーンに生かします。
#
# ### 7. ユーザー生成コンテンツ
# - **顧客の声を活用する**: ユーザーによるレビューやSNSでの投稿を促進し、さらに信頼性を高めます。
#
# これらのステップを踏むことで、新製品の発売に向けた効果的なマーケティング戦略を構築し、成功に導くことができるでしょう。具体的な製品や市場に応じて、戦略を調整することも重要です。
